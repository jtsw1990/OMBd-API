# %% [markdown]
# ### This mini project consists of the beginning of the pipeline, where unprocessed data is queried from the IMDb API in JSON format and finally basic EDA is carried out on a processed pandas dataframe

# %%
import os, sys, requests, json
import pandas as pd
import numpy as np
from numpy.random import randint
import matplotlib.pyplot as plt
np.random.seed(123)

# %%
domain = 'http://www.omdbapi.com/?apikey='
query = '&i='
api_key = '98b8e0fb'
code = 'tt'

# %%
id_collected = []
start_id = 1100000
len_id = 100
def gen_id(start_id,len_id):
    '''Generates a variable list of all collected imdb IDs depending on start and length'''
    for num in range(len_id):
        imdb_ord = start_id + num
        imdb_id = code + str(imdb_ord)
        id_collected.append(imdb_id)
    return id_collected
    
total_list =[]
throw_away =[]
series_list =[]

def get_series(api_key):
    '''This function will take the queries as inputs and churn out the JSON data'''
    try:
        global domain
        for series in gen_id(start_id, len_id): 
            url = domain + api_key + query + series
            response = requests.get(url).json()
            data_dict = dict(response)
            total_list.append(data_dict)
    except:
        pass
    return total_list

# %%
total_list = get_series(api_key)
def get_sublists(film_type):
    '''This function acts as a boolean condition for whatever movies you want to keep from that long list'''
    for film in total_list:
        if film['Response'] == 'True':
            if film['Type'] == film_type:
                series_list.append(film)
        else:
            del film             
    return series_list

# %%
#Quick check to make sure above function is working properly
for film in get_sublists('movie'):
    print('%s is a %s' % (film['Title'],film['Type']))
# Out:
# Over is a movie
# Raising the Bar is a movie
# The Rod Squad is a movie
# Sachta pohrbených ideí is a movie
# Samt und Seide - Historische Stoffe aus Florenz is a movie
# The Secret Treasure is a movie
# Sendaihagi hagi no ishizûe is a movie
# Sex-Tour durch Zürich is a movie
# Soir bleu is a movie
# The Spotted Elephant Hawk Moth is a movie
# Starshots, Volume One is a movie
# Straw Hats Made in Florence, Italy is a movie
# Stín ve svetle is a movie
# Submarine Fauna is a movie
# Les superpouvoirs de la taupe is a movie
# Svatební kosile is a movie
# Svejk na fronte is a movie
# Sílený lékar is a movie
# Tahiti, the Picturesque is a movie
# Tamaterûhime is a movie
# To Paint the Portrait of a Bird is a movie
# Toad Traits is a movie
# Tomie vs Tomie is a movie
# Tonight We Fly is a movie
# Tough Guy Levi is a movie
# UFC 75: Champion vs. Champion is a movie
# Venetian Lace Workers is a movie
# Verhext - Von zauberhaften Fick-Mäusen verführt... is a movie
# Wifey's Ma Comes Back is a movie
# Wildflowers of Manitoba is a movie
# Worry Wart is a movie
# X-Day is a movie
# The Young Cadets is a movie
# Young Hearts and Old is a movie
# Young, Hard, & Solo #20 is a movie
# 35 Shots of Rum is a movie
# Bereavement is a movie
# Shadows is a movie
# Tormented is a movie
# Adil e Yusuf is a movie
# Astah is a movie
# Beginning of an Affair is a movie
# Benito y el peluquero is a movie
# Blind Man's Eye is a movie
# California My Way is a movie
# Cargo is a movie
# Carlo Goldoni Venezian is a movie
# Cavalcade of Champions is a movie
# Chambr'a is a movie
# #DUPE# is a movie
# Dios de 2 mundos is a movie
# Duetto dei gatti is a movie
# Equilibrio is a movie
# Johann Wolfgang von Goethe: Faust I is a movie
# Foxcatcher is a movie
# Free Spirits is a movie
# Friends Forever is a movie
# Fußballgöttinnen is a movie
# George Michael: Twenty Five is a movie
# Gödel is a movie
# Habanero is a movie
# Al-hadiya is a movie
# Hilda und Willi is a movie
# Huge is a movie
# In the Caucasian Mountains is a movie

# %%
#At this point in time, manipulation of data really depends on the nature of the hypothesis
#Here i chose to extract and examine the relationship between IMDb's score and year of release with a small subset
criteria = ['Title','Year','imdbRating']
df = []
for film in get_sublists('movie'):
    rows = (film[criteria[0]],film[criteria[1]],film[criteria[2]])
    df.append(rows)
final = pd.DataFrame(df)
final.columns = criteria
final = final.drop_duplicates().replace('N/A',np.nan).dropna(how='any')
final
# Out:
#                                   Title  Year imdbRating
# 0                                  Over  2006        5.0
# 1                       Raising the Bar  2007        8.2
# 20      To Paint the Portrait of a Bird  2007        8.4
# 22                       Tomie vs Tomie  2007        5.3
# 25        UFC 75: Champion vs. Champion  2007        7.7
# 35                      35 Shots of Rum  2008        7.1
# 36                          Bereavement  2010        5.1
# 38                            Tormented  2009        5.2
# 39                         Adil e Yusuf  2007        7.8
# 42                Benito y el peluquero  2007        6.9
# 45                                Cargo  2007        6.2
# 53  Johann Wolfgang von Goethe: Faust I  2001        7.8
# 54                           Foxcatcher  2014        7.0
# 55                         Free Spirits  2007        7.6
# 56                      Friends Forever  2007        7.5
# 57                     Fußballgöttinnen  2006        5.8
# 58          George Michael: Twenty Five  2006        7.2
# 59                                Gödel  2007        7.1
# 60                             Habanero  2007        7.9
